# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

requests = pd.read_csv("211-dataset.csv", "county")

requests.plot()
# Out:
# <ipython-input-3-52020f345e4e>:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   requests = pd.read_csv("211-dataset.csv", "county")
